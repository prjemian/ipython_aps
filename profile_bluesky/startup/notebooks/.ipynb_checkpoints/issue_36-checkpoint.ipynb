# %% [markdown]
# # add stream with tuning results
#
# per [APS_Bluesky_tools issue #36](https://github.com/BCDA-APS/APS_BlueSky_tools/issues/36)

# %%
from ophyd.scaler import ScalerCH
from ophyd import EpicsMotor
from APS_BlueSky_tools.devices import use_EPICS_scaler_channels
from bluesky import RunEngine
import bluesky.plans as bp
from bluesky.callbacks.best_effort import BestEffortCallback

# %matplotlib notebook
from bluesky.utils import install_nb_kicker
install_nb_kicker()

RE = RunEngine({})
RE.subscribe(BestEffortCallback())

m1 = EpicsMotor("gov:m1", name="m1")
scaler = ScalerCH("gov:scaler1", name="scaler")
scaler.match_names()
use_EPICS_scaler_channels(scaler)
for k, v in scaler.read().items():
    print(k, v)
#print(scaler.read(), "\n")
print("scaler.preset_time", scaler.preset_time.value)
# Out:
# clock {'value': 4000000.0, 'timestamp': 1535647626.284175}
# I0 {'value': 1.0, 'timestamp': 1535647626.284175}
# scint {'value': 1.0, 'timestamp': 1535647626.284175}
# scaler_time {'value': 0.4, 'timestamp': 1535647626.284175}
# scaler.preset_time 0.25

# %%
RE(bp.count([scaler]))
# Out:
# Transient Scan ID: 1     Time: 2018/08/30 11:48:46
# Persistent Unique Scan ID: '1dfbbed2-5ffd-4a35-81e8-b3f606cde856'
# New stream: 'primary'
# +-----------+------------+------------+------------+------------+
# |   seq_num |       time |      clock |         I0 |      scint |
# +-----------+------------+------------+------------+------------+
# |         1 | 11:48:47.7 |    4000000 |          2 |          2 |
# +-----------+------------+------------+------------+------------+
# generator count ['1dfbbed2'] (scan num: 1)
# ('1dfbbed2-5ffd-4a35-81e8-b3f606cde856',)

# %%
RE(bp.scan([scaler], m1, -1, 1, 5))
# Out:
# Transient Scan ID: 2     Time: 2018/08/30 11:48:47
# Persistent Unique Scan ID: '2e4f47ba-9db6-45e6-a19e-aed1565d980a'
# New stream: 'primary'
# +-----------+------------+------------+------------+------------+------------+
# |   seq_num |       time |         m1 |      clock |         I0 |      scint |
# +-----------+------------+------------+------------+------------+------------+
# |         1 | 11:48:49.0 |   -1.00000 |    4000000 |          2 |          2 |
# |         2 | 11:48:49.9 |   -0.50000 |    4000000 |          1 |          1 |
# |         3 | 11:48:50.7 |    0.00000 |    4000000 |          2 |          0 |
# |         4 | 11:48:51.5 |    0.50000 |    4000000 |          2 |          1 |
# |         5 | 11:48:52.3 |    1.00000 |    4000000 |          2 |          2 |
# +-----------+------------+------------+------------+------------+------------+
# generator scan ['2e4f47ba'] (scan num: 2)
# ('2e4f47ba-9db6-45e6-a19e-aed1565d980a',)
